# %%
from matplotlib import pyplot as plt
import json


with open("../../data/results/solution-quality-test.json", 'r', encoding='utf-8') as file:
    data_dict = json.load(file)

x_values = data_dict["100"]["z_values"]
plt.boxplot(x_values, showmeans=True, meanline=True, vert=True, labels=["100"])

#plt.set_title("Boxplot")
#plt.set_xlabel()
#ax.set_ylabel("Total Tour Length")

#plt.savefig(output_title)

plt.show()
